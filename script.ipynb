-- %%
.param set age 10
.param set name Alex
-- Out:
-- [no code]

-- %%
select 1 + 2, :name, :age;
-- Out:
-- ┌───────┬───────┬──────┐
-- │ 1 + 2 │ :name │ :age │
-- ├───────┼───────┼──────┤
-- │     3 │ Alex  │ 10   │
-- └───────┴───────┴──────┘

-- %%
select 'second cell!' as woa;
-- Out:
-- ┌──────────────┐
-- │ woa          │
-- ├──────────────┤
-- │ second cell! │
-- └──────────────┘

-- %%
select *
from "./tests/latimes-place-totals.csv"
limit 20;
-- Out:
-- ┌───────┬──────────────────────┬────────────┬─────────┬──────┬─────────────────┬──────┬────────────┐
-- │ id    │ name                 │ date       │ county  │ fips │ confirmed_cases │ note │ population │
-- ├───────┼──────────────────────┼────────────┼─────────┼──────┼─────────────────┼──────┼────────────┤
-- │ 94501 │ 94501: Alameda       │ 2023-02-17 │ Alameda │ 001  │ 12253           │      │ 62826      │
-- │ 94502 │ 94502: Alameda       │ 2023-02-17 │ Alameda │ 001  │ 2102            │      │ 14117      │
-- │ 94505 │ 94505: Discovery Bay │ 2023-02-17 │ Alameda │ 001  │ 3               │      │ 16382      │
-- │ 94514 │ 94514: Byron         │ 2023-02-17 │ Alameda │ 001  │ 2               │      │ 1461       │
-- │ 94536 │ 94536: Fremont       │ 2023-02-17 │ Alameda │ 001  │ 13991           │      │ 72976      │
-- │ 94538 │ 94538: Fremont       │ 2023-02-17 │ Alameda │ 001  │ 14666           │      │ 63911      │
-- ...

-- %%
select *
from "./tests/latimes-place-totals.csv"
where name like '%whittier%'
limit 20;
